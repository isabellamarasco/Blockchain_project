# %%
#import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#open dataset.csv
df = pd.read_csv('dataset/dataset.csv')

# %% [markdown]
# ### Data visualization

# %%
#view number of rows and columns
print(df.shape)
#view first 5 rows
display(df.head())
# Out:
# (1598014, 26)
#                     id                created_at  \
# 0  1356028911554088962  2021-01-31T23:57:40.000Z
# 1  1356029465780957184  2021-01-31T23:59:53.000Z
# 2  1354012224008974336  2021-01-26T10:24:05.000Z
# 3  1356029400056291335  2021-01-31T23:59:37.000Z
# 4  1356029224277209088  2021-01-31T23:58:55.000Z
#
#                                                 text            author.id  \
# 0  O Álvaro Garnero ficou bem à vontade na praia....            306507744
# 1  @DomEspetacular Gente,que lugar é esse Álvaro?...   941330352353800192
# 2  Medium-scale #farms in #Nigeria 🇳🇬 with access...            292988442
# 3  @FutureAgrics @FCDOAgResearch @IDS_UK @MSUAFRE...  1340303730625949697
# 4  Hey! Managing your crypto would be so much eas...  1155606797195124736
#
#    author.username          author.name  \
# 0   DomEspetacular  Domingo Espetacular
# 1  JurandirDeNapo7  Jurandir De Napoles
# 2     FutureAgrics  Future Agricultures
# 3   OhreeeOfficial           Ohreee.eth
# 4        schabrand         sachatouille
#
#    author.public_metrics.followers_count  author.public_metrics.listed_count  \
# 0                                 350588                                 203
# 1                                     23                                   0
# 2                                  22365                                 241
# 3                                    577                                   5
# 4                                    157                                   8
#
#    author.verified      conversation_id  ...            geo.id   geo.name  \
# 0             True  1356028911554088962  ...               NaN        NaN
# 1            False  1356028911554088962  ...  68e019afec7d0ba5  San Paolo
# 2            False  1354012224008974336  ...               NaN        NaN
# 3            False  1354012224008974336  ...  01eddd9d0dbec2c8      Ikeja
# 4            False  1356029224277209088  ...  35c549e080e5518e       Rezé
#
#   lang public_metrics.like_count public_metrics.quote_count  \
# 0   pt                        31                          1
# 1   pt                         0                          0
# 2   en                        39                          0
# 3   en                         0                          0
# 4   en                         0                          0
#
#   public_metrics.reply_count public_metrics.retweet_count  \
# 0                         15                            2
# 1                          0                            0
# 2                          1                            8
# 3                          0                            0
# 4                          0                            0
#
#                                    referenced_tweets        type  Unnamed: 93
# 0                                                NaN  replied_to          NaN
# 1  [{"type": "replied_to", "id": "135602891155408...         NaN          NaN
# 2                                                NaN  replied_to          NaN
# 3  [{"type": "replied_to", "id": "135401222400897...         NaN          NaN
# 4                                                NaN         NaN          NaN
#
# [5 rows x 26 columns]

# %%
#plot the number of tweet to every year from created_at column and geo.country column
df['created_at'] = pd.to_datetime(df['created_at'])
df['year'] = df['created_at'].dt.year
df['year'].value_counts().sort_index().plot(kind='bar')
plt.title('Number of tweets to every year')
plt.xlabel('Year')
plt.ylabel('Number of tweets')
plt.show()
