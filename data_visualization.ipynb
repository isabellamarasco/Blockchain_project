# %%
#import
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
file= pd.read_csv('dataset/2023-01.csv')
display(file.head(3))
# Out:
# /var/folders/dn/3rzmgvf53gv2ssvdr1f517gc0000gn/T/ipykernel_2596/2878793624.py:1: DtypeWarning: Columns (31,33,75,86,87,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   file= pd.read_csv('dataset/2023-01.csv')
#                     id                created_at  \
# 0  1620391799302033409  2023-01-31T12:01:25.000Z
# 1  1620572262649954304  2023-01-31T23:58:30.000Z
# 2  1620422397278158849  2023-01-31T14:03:00.000Z
#
#                                                 text attachments.media  \
# 0  Ministro de Lula usou R$ 565 mil do fundão ele...               NaN
# 1  @TerraBrasilnot Nada é comum nessa terra isso ...               NaN
# 2  Gm! ☕️ Life is good! Morning walks are the bes...              [{}]
#
#       attachments.media_keys  attachments.poll.duration_minutes  \
# 0                        NaN                                NaN
# 1                        NaN                                NaN
# ...
